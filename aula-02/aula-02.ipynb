# %%
#importa a biblioteca do pandas
import pandas as pd

# %%
#importa a base de dados
vendas = pd.read_excel('base_vendas.xlsx')

# %%
#lê a base de dados
vendas.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18            1.0
# 1                    2018-08-13            1.0
# 2                    2018-09-04            1.0
#
#                          product_id  ...   price freight_value  \
# 0  87285b34884572647811a353c7ac498a  ...   29.99          8.72
# 1  595fac2a385ac33a80bd5114aec74eb8  ...  118.70         22.76
# 2  aa4383b373c6aca5d8797843e5594415  ...  159.90         19.22
#
#    product_category_name                customer_unique_id customer_city  \
# 0  utilidades_domesticas  7c396fd4830fd04220f754e42b4e5bff     sao paulo
# 1             perfumaria  af07308b275d755c9edb36a90c618231     barreiras
# 2             automotivo  3a653a41f6f9fc3d2a113cf8398680e8    vianopolis
#
#   customer_state dia_compra mes_compra  ano_compra  ano_mes
# 0             SP          2         10        2017  2017-10
# 1             BA         24          7        2018  2018-07
# 2             GO          8          8        2018  2018-08
#
# [3 rows x 22 columns]

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111923 entries, 0 to 111922
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       111923 non-null  object
#  1   customer_id                    111923 non-null  object
#  2   order_status                   111923 non-null  object
#  3   order_purchase_timestamp       111923 non-null  datetime64[ns]
#  4   order_approved_at              111808 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   110050 non-null  datetime64[ns]
#  6   order_delivered_customer_date  108804 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  111923 non-null  datetime64[ns]
#  8   order_item_id                  111206 non-null  float64
#  9   product_id                     111206 non-null  object
#  10  seller_id                      111206 non-null  object
#  11  shipping_limit_date            111206 non-null  datetime64[ns]
#  12  price                          111206 non-null  float64
#  13  freight_value                  111206 non-null  float64
#  14  product_category_name          109608 non-null  object
#  15  customer_unique_id             111923 non-null  object
#  16  customer_city                  111923 non-null  object
#  17  customer_state                 111923 non-null  object
#  18  dia_compra                     111923 non-null  int64
#  19  mes_compra                     111923 non-null  int64
#  20  ano_compra                     111923 non-null  int64
#  21  ano_mes                        111923 non-null  object
# dtypes: datetime64[ns](6), float64(3), int64(3), object(10)
# memory usage: 18.8+ MB

# %%
vendas.describe()
# Out:
#        order_item_id          price  freight_value     dia_compra  \
# count  111206.000000  111206.000000  111206.000000  111923.000000
# mean        1.198020     120.845955      20.032079      15.512853
# std         0.706445     183.941756      15.847991       8.667442
# min         1.000000       0.850000       0.000000       1.000000
# 25%         1.000000      39.900000      13.080000       8.000000
# 50%         1.000000      74.990000      16.280000      15.000000
# 75%         1.000000     134.990000      21.180000      23.000000
# max        21.000000    6735.000000     409.680000      31.000000
#
#           mes_compra     ano_compra
# count  111923.000000  111923.000000
# mean        6.000670    2017.541167
# std         3.241051       0.498305
# min         1.000000    2017.000000
# 25%         3.000000    2017.000000
# 50%         6.000000    2018.000000
# 75%         8.000000    2018.000000
# max        12.000000    2018.000000

# %%
#importa a base de dados
pagamentos = pd.read_excel('base_pagamentos.xlsx')

# %%
#lê a base de dados
pagamentos.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2017-10-02        2017-10-02
# 2    delivered               2017-10-02        2017-10-02
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2017-10-04                    2017-10-10
# 2                   2017-10-04                    2017-10-10
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                   1  credit_card
# 1                    2017-10-18                   2      voucher
# 2                    2017-10-18                   3      voucher
#
#    payment_installments  payment_value
# 0                     1          18.12
# 1                     1          18.59
# 2                     1           2.00

# %%
pagamentos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102528 entries, 0 to 102527
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       102528 non-null  object
#  1   customer_id                    102528 non-null  object
#  2   order_status                   102528 non-null  object
#  3   order_purchase_timestamp       102528 non-null  datetime64[ns]
#  4   order_approved_at              102399 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   100730 non-null  datetime64[ns]
#  6   order_delivered_customer_date  99500 non-null   datetime64[ns]
#  7   order_estimated_delivery_date  102528 non-null  datetime64[ns]
#  8   payment_sequential             102528 non-null  int64
#  9   payment_type                   102528 non-null  object
#  10  payment_installments           102528 non-null  int64
#  11  payment_value                  102528 non-null  float64
# dtypes: datetime64[ns](5), float64(1), int64(2), object(4)
# memory usage: 9.4+ MB

# %%
pagamentos.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count        102528.00000         102528.000000  102528.000000
# mean              1.09337              2.854332     154.309690
# std               0.71027              2.686302     217.916223
# min               1.00000              0.000000       0.000000
# 25%               1.00000              1.000000      56.860000
# 50%               1.00000              1.000000     100.000000
# 75%               1.00000              4.000000     172.080000
# max              29.00000             24.000000   13664.080000

# %%
pagamentos.head(2)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2017-10-02        2017-10-02
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2017-10-04                    2017-10-10
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                   1  credit_card
# 1                    2017-10-18                   2      voucher
#
#    payment_installments  payment_value
# 0                     1          18.12
# 1                     1          18.59

# %%
pagamentos.shape
# Out:
# (102528, 12)

# %%
#mostra os dados da coluna payment_type
pagamentos.payment_type
# Out:
# 0         credit_card
# 1             voucher
# 2             voucher
# 3              boleto
# 4         credit_card
#              ...
# 102523    credit_card
# 102524    credit_card
# 102525    credit_card
# 102526    credit_card
# 102527     debit_card
# Name: payment_type, Length: 102528, dtype: object

# %%
#conta o total de "payment_type"
pagamentos.payment_type.count()
# Out:
# 102528

# %%
#conta os valores da coluna "payment_type"
pagamentos.payment_type.value_counts()
# Out:
# credit_card    75809
# boleto         19543
# voucher         5690
# debit_card      1486
# Name: payment_type, dtype: int64

# %%
#calculando a porcentagem dos tipos de "payment_type"
transacoes_total = pagamentos.payment_type.count()
transacoes_tipo = pagamentos.payment_type.value_counts()
round((transacoes_tipo/transacoes_total) * 100,2)
# Out:
# credit_card    73.94
# boleto         19.06
# voucher         5.55
# debit_card      1.45
# Name: payment_type, dtype: float64

# %%
transacoes_tipo.credit_card
# Out:
# 75809

# %%
#quantas vezes o valor de transações de cartao de credito é mair do que o de voleto
transacoes_tipo.credit_card/transacoes_tipo.boleto
# Out:
# 3.8790871411758685

# %%
#mostrar os valores em grafico
transacoes_tipo.plot()
# Out:
# <AxesSubplot:>

# %%
#mostrar os valores em grafico de barra (bar) ou em barra horizontal (barh)
transacoes_tipo.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#salvar o grafico em png
import matplotlib.pyplot as plt
transacoes_tipo.plot.bar()
plt.savefig('transacoes_tipo')

# %%
#verificar o número de parcelas "payment_installments"
pagamentos.payment_installments.value_counts()
# Out:
# 1     51817
# 2     12255
# 3     10335
# 4      7015
# 10     5247
# 5      5184
# 8      4232
# 6      3872
# 7      1598
# 9       637
# 12      132
# 15       72
# 18       27
# 11       22
# 24       18
# 20       17
# 13       15
# 14       15
# 17        7
# 16        4
# 21        3
# 0         2
# 23        1
# 22        1
# Name: payment_installments, dtype: int64

# %%
pagamentos.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2017-10-02        2017-10-02
# 2    delivered               2017-10-02        2017-10-02
# 3    delivered               2018-07-24        2018-07-26
# 4    delivered               2018-08-08        2018-08-08
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2017-10-04                    2017-10-10
# 2                   2017-10-04                    2017-10-10
# 3                   2018-07-26                    2018-08-07
# 4                   2018-08-08                    2018-08-17
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                   1  credit_card
# 1                    2017-10-18                   2      voucher
# 2                    2017-10-18                   3      voucher
# 3                    2018-08-13                   1       boleto
# 4                    2018-09-04                   1  credit_card
#
#    payment_installments  payment_value
# 0                     1          18.12
# 1                     1          18.59
# 2                     1           2.00
# 3                     1         141.46
# 4                     3         179.12

# %%
#filtar dados com tipo de pagamento (payment_type) em "credit_card"
pagamentos.loc[pagamentos.payment_type == 'credit_card']
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 6       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 7       a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# ...                                  ...                               ...
# 102522  880675dff2150932f1601e1c07eadeeb  47cd45a6ac7b9fb16537df2ccffeb5ac
# 102523  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 102524  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 102525  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 102526  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
#
#        order_status order_purchase_timestamp order_approved_at  \
# 0         delivered               2017-10-02        2017-10-02
# 4         delivered               2018-08-08        2018-08-08
# 5         delivered               2017-11-18        2017-11-18
# 6         delivered               2018-02-13        2018-02-13
# 7         delivered               2017-07-09        2017-07-09
# ...             ...                      ...               ...
# 102522    delivered               2017-02-23        2017-02-23
# 102523    delivered               2017-03-09        2017-03-09
# 102524    delivered               2018-02-06        2018-02-06
# 102525    delivered               2017-08-27        2017-08-27
# 102526    delivered               2018-01-08        2018-01-08
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0                        2017-10-04                    2017-10-10
# 4                        2018-08-08                    2018-08-17
# 5                        2017-11-22                    2017-12-02
# 6                        2018-02-14                    2018-02-16
# 7                        2017-07-11                    2017-07-26
# ...                             ...                           ...
# 102522                   2017-03-01                    2017-03-06
# 102523                   2017-03-10                    2017-03-17
# 102524                   2018-02-07                    2018-02-28
# 102525                   2017-08-28                    2017-09-21
# 102526                   2018-01-12                    2018-01-25
#
#        order_estimated_delivery_date  payment_sequential payment_type  \
# 0                         2017-10-18                   1  credit_card
# 4                         2018-09-04                   1  credit_card
# 5                         2017-12-15                   1  credit_card
# 6                         2018-02-26                   1  credit_card
# 7                         2017-08-01                   1  credit_card
# ...                              ...                 ...          ...
# 102522                    2017-03-22                   1  credit_card
# 102523                    2017-03-28                   1  credit_card
# 102524                    2018-03-02                   1  credit_card
# 102525                    2017-09-27                   1  credit_card
# 102526                    2018-02-15                   1  credit_card
#
#         payment_installments  payment_value
# 0                          1          18.12
# 4                          3         179.12
# 5                          1          72.20
# 6                          1          28.62
# 7                          6         175.26
# ...                      ...            ...
# 102522                     3         155.99
# 102523                     3          85.08
# 102524                     3         195.00
# 102525                     5         271.01
# 102526                     4         441.16
#
# [75809 rows x 12 columns]

# %%
#pegar coluna com número de parcelas () com filtro (credit_card)
pagamentos.loc[pagamentos.payment_type == 'credit_card', 'payment_installments']
# Out:
# 0         1
# 4         3
# 5         1
# 6         1
# 7         6
#          ..
# 102522    3
# 102523    3
# 102524    3
# 102525    5
# 102526    4
# Name: payment_installments, Length: 75809, dtype: int64

# %%
#verificar o número de parcelas "payment_installments" com filtro (credit_card)
pagamentos.loc[pagamentos.payment_type == 'credit_card', 'payment_installments'].value_counts()
# Out:
# 1     25098
# 2     12255
# 3     10335
# 4      7015
# 10     5247
# 5      5184
# 8      4232
# 6      3872
# 7      1598
# 9       637
# 12      132
# 15       72
# 18       27
# 11       22
# 24       18
# 20       17
# 13       15
# 14       15
# 17        7
# 16        4
# 21        3
# 0         2
# 23        1
# 22        1
# Name: payment_installments, dtype: int64

# %%
#verificar o número de parcelas "payment_installments" com filtro (credit_card) ordenado pelo index
pagamentos.loc[pagamentos.payment_type == 'credit_card', 'payment_installments'].value_counts().sort_index()
# Out:
# 0         2
# 1     25098
# 2     12255
# 3     10335
# 4      7015
# 5      5184
# 6      3872
# 7      1598
# 8      4232
# 9       637
# 10     5247
# 11       22
# 12      132
# 13       15
# 14       15
# 15       72
# 16        4
# 17        7
# 18       27
# 20       17
# 21        3
# 22        1
# 23        1
# 24       18
# Name: payment_installments, dtype: int64

# %%
#passando os dados para um grafico
pagamento_parcelado = pagamentos.loc[pagamentos.payment_type == 'credit_card', 'payment_installments'].value_counts().sort_index()

pagamento_parcelado.plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#exportar figura

pagamento_parcelado.plot.bar(figsize=(10,5))
plt.savefig('pagamento_parcelado', bbox_inches='tight', transparent=True)

# %%
#calculando o percentual

total_parcelado = pagamento_parcelado.sum()
round((pagamento_parcelado/total_parcelado) * 100,2)
# Out:
# 0      0.00
# 1     33.11
# 2     16.17
# 3     13.63
# 4      9.25
# 5      6.84
# 6      5.11
# 7      2.11
# 8      5.58
# 9      0.84
# 10     6.92
# 11     0.03
# 12     0.17
# 13     0.02
# 14     0.02
# 15     0.09
# 16     0.01
# 17     0.01
# 18     0.04
# 20     0.02
# 21     0.00
# 22     0.00
# 23     0.00
# 24     0.02
# Name: payment_installments, dtype: float64

# %%
#passar para grafico

round((pagamento_parcelado/total_parcelado) * 100,2).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Analizando valor de parcelas**

# %%
#vendo os valores
pagamentos.payment_value.count()
# Out:
# 102528

# %%
#vendo o total dos valores
pagamentos.payment_value.sum()
# Out:
# 15821063.889999997

# %%
#verificando o valor médio das parcelas
pagamentos.payment_value.sum() / pagamentos.payment_value.count()
# Out:
# 154.30968993835828

# %%
#calculando a m,edia diretamente 
pagamentos.payment_value.mean()
# Out:
# 154.30968993835828

# %%
pagamentos.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2017-10-02        2017-10-02
# 2    delivered               2017-10-02        2017-10-02
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2017-10-04                    2017-10-10
# 2                   2017-10-04                    2017-10-10
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                   1  credit_card
# 1                    2017-10-18                   2      voucher
# 2                    2017-10-18                   3      voucher
#
#    payment_installments  payment_value
# 0                     1          18.12
# 1                     1          18.59
# 2                     1           2.00

# %%
#media por tipo de pagamento
pagamentos.groupby('payment_type')['payment_value'].mean()
# Out:
# payment_type
# boleto         145.430333
# credit_card    163.530169
# debit_card     143.290572
# voucher         64.838404
# Name: payment_value, dtype: float64

# %%
#valor total por tipo de pagamento
pagamentos.groupby('payment_type')['payment_value'].sum().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    12397058.59
# boleto          2842144.99
# voucher          368930.52
# debit_card       212929.79
# Name: payment_value, dtype: float64

# %%
#passando para grafico
pagamentos.groupby('payment_type')['payment_value'].sum().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='payment_type'>

# %%
from statistics import mean


pagamentos[pagamentos.payment_type == 'credit_card'].groupby('payment_installments')['payment_value'].mean()
# Out:
# payment_installments
# 0      94.315000
# 1      96.133129
# 2     127.260781
# 3     142.776074
# 4     164.268574
# 5     183.344851
# 6     210.148698
# 7     188.499869
# 8     308.104910
# 9     203.799953
# 10    414.834061
# 11    125.478636
# 12    323.144470
# 13    151.318000
# 14    167.962667
# 15    451.722083
# 16    285.677500
# 17    174.224286
# 18    486.483333
# 20    615.801765
# 21    243.700000
# 22    228.710000
# 23    236.480000
# 24    610.048889
# Name: payment_value, dtype: float64

# %% [markdown]
# **Sobre Vendas**

# %%
vendas.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18            1.0
# 1                    2018-08-13            1.0
# 2                    2018-09-04            1.0
#
#                          product_id  ...   price freight_value  \
# 0  87285b34884572647811a353c7ac498a  ...   29.99          8.72
# 1  595fac2a385ac33a80bd5114aec74eb8  ...  118.70         22.76
# 2  aa4383b373c6aca5d8797843e5594415  ...  159.90         19.22
#
#    product_category_name                customer_unique_id customer_city  \
# 0  utilidades_domesticas  7c396fd4830fd04220f754e42b4e5bff     sao paulo
# 1             perfumaria  af07308b275d755c9edb36a90c618231     barreiras
# 2             automotivo  3a653a41f6f9fc3d2a113cf8398680e8    vianopolis
#
#   customer_state dia_compra mes_compra  ano_compra  ano_mes
# 0             SP          2         10        2017  2017-10
# 1             BA         24          7        2018  2018-07
# 2             GO          8          8        2018  2018-08
#
# [3 rows x 22 columns]

# %%
#verificando valores nulos
vendas.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 115
# order_delivered_carrier_date     1873
# order_delivered_customer_date    3119
# order_estimated_delivery_date       0
# order_item_id                     717
# product_id                        717
# seller_id                         717
# shipping_limit_date               717
# price                             717
# freight_value                     717
# product_category_name            2315
# customer_unique_id                  0
# customer_city                       0
# customer_state                      0
# dia_compra                          0
# mes_compra                          0
# ano_compra                          0
# ano_mes                             0
# dtype: int64

# %%
#ver a soma do preço pago peço cliente
preco = vendas.price.sum()
preco
# Out:
# 13438795.230000002

# %%
#soma do valor total na base de pagamentos
pagamentos.payment_value.sum()
# Out:
# 15821063.889999997

# %%
#valor do frete
frete = vendas.freight_value.sum()
frete
# Out:
# 2227687.37

# %%
preco + frete
# Out:
# 15666482.600000001

# %%
#valores onde o preço é nulo
vendas.loc[vendas.price.isnull(), 'order_id']
# Out:
# 300       8e24261a7e58791d10cb1bf9da94df5c
# 658       c272bcd21c287498b4883c7512019702
# 778       37553832a3a89c9b2db59701c357ca67
# 834       d57e15fb07fd180f06ab3926b39edcd2
# 1302      2f634e2cebf8c0283e7ef0989f77d217
#                         ...
# 111597    6cf5c427fb11bc5fe8abefa86aa7ba0b
# 111691    1c7c8ab324927f5b6e52338bd110bef4
# 111709    aaab15da689073f8f9aa978a390a69d1
# 111824    a69ba794cc7deb415c3e15a0a3877e69
# 111895    5fabc81b6322c8443648e1b21a6fef21
# Name: order_id, Length: 717, dtype: object

# %%
#verificando na base de pagamentos
pagamentos[pagamentos.order_id == '8e24261a7e58791d10cb1bf9da94df5c']
# Out:
#                              order_id                       customer_id  \
# 275  8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
#
#     order_status order_purchase_timestamp order_approved_at  \
# 275  unavailable               2017-11-16        2017-11-16
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 275                          NaT                           NaT
#
#     order_estimated_delivery_date  payment_sequential payment_type  \
# 275                    2017-12-05                   1  credit_card
#
#      payment_installments  payment_value
# 275                     5           84.0

# %%
#de forma mais escalonavel

ids = vendas.loc[vendas.price.isnull(), 'order_id']

pagamentos[pagamentos.order_id.isin(ids)]
# Out:
#                                 order_id                       customer_id  \
# 275     8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 603     c272bcd21c287498b4883c7512019702  9582c5bbecc65eb568e2c1d839b5cba1
# 705     37553832a3a89c9b2db59701c357ca67  7607cd563696c27ede287e515812d528
# 753     d57e15fb07fd180f06ab3926b39edcd2  470b93b3f1cde85550fc74cd3a476c78
# 1184    2f634e2cebf8c0283e7ef0989f77d217  7353b0fb8e8d9675e3a704c60ca44ebe
# ...                                  ...                               ...
# 102320  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 102321  1c7c8ab324927f5b6e52338bd110bef4  95b1767df51d6fa09402267d8de314df
# 102339  aaab15da689073f8f9aa978a390a69d1  df20748206e4b865b2f14a5eabbfcf34
# 102434  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 102500  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#        order_status order_purchase_timestamp order_approved_at  \
# 275     unavailable               2017-11-16        2017-11-16
# 603     unavailable               2018-01-31        2018-01-31
# 705     unavailable               2017-08-14        2017-08-17
# 753     unavailable               2018-01-08        2018-01-09
# 1184    unavailable               2017-09-27        2017-09-28
# ...             ...                      ...               ...
# 102320  unavailable               2017-12-23        2017-12-23
# 102321  unavailable               2017-12-23        2017-12-23
# 102339  unavailable               2018-01-16        2018-01-17
# 102434  unavailable               2017-08-23        2017-08-28
# 102500  unavailable               2017-10-10        2017-10-14
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 275                             NaT                           NaT
# 603                             NaT                           NaT
# 705                             NaT                           NaT
# 753                             NaT                           NaT
# 1184                            NaT                           NaT
# ...                             ...                           ...
# 102320                          NaT                           NaT
# 102321                          NaT                           NaT
# 102339                          NaT                           NaT
# 102434                          NaT                           NaT
# 102500                          NaT                           NaT
#
#        order_estimated_delivery_date  payment_sequential payment_type  \
# 275                       2017-12-05                   1  credit_card
# 603                       2018-02-16                   1  credit_card
# 705                       2017-09-05                   1       boleto
# 753                       2018-02-06                   1       boleto
# 1184                      2017-10-27                   1  credit_card
# ...                              ...                 ...          ...
# 102320                    2018-01-19                   1  credit_card
# 102321                    2018-01-19                   2      voucher
# 102339                    2018-02-06                   1       boleto
# 102434                    2017-09-15                   1  credit_card
# 102500                    2017-10-23                   1       boleto
#
#         payment_installments  payment_value
# 275                        5          84.00
# 603                        1          97.68
# 705                        1         132.46
# 753                        1         134.38
# 1184                      12         615.53
# ...                      ...            ...
# 102320                     3         110.09
# 102321                     1         824.00
# 102339                     1         210.09
# 102434                     2         195.91
# 102500                     1         133.97
#
# [772 rows x 12 columns]

# %%
#valor total dos ids
diferenca_nulos = pagamentos.loc[pagamentos.order_id.isin(ids), 'payment_value'].sum()

# %%
#encontrar toda a diferença
frete+preco+diferenca_nulos
# Out:
# 15818217.510000002

# %% [markdown]
# **Exemplos de ordens:**
# - ce6d150fb29ada17d2082f4847107665
# - 70b742795bc441e94a44a084b6d9ce7a
# - 996c7e73600ad3723e8627ab7bef81e4

# %%
#verificando a ordem na base de vendas
vendas[vendas.order_id == 'ce6d150fb29ada17d2082f4847107665']
# Out:
#                                order_id                       customer_id  \
# 13161  ce6d150fb29ada17d2082f4847107665  d8acb46c718975948423dbf1b603b959
#
#       order_status order_purchase_timestamp order_approved_at  \
# 13161    delivered               2018-01-25        2018-01-27
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 13161                   2018-01-29                    2018-02-21
#
#       order_estimated_delivery_date  order_item_id  \
# 13161                    2018-03-08            1.0
#
#                              product_id  ...   price freight_value  \
# 13161  638bbb2a5e4f360b71f332ddfebfd672  ...  1299.0        104.66
#
#                    product_category_name                customer_unique_id  \
# 13161  construcao_ferramentas_construcao  3629a4b18f2eb69e03f153158e48d2cc
#
#        customer_city customer_state dia_compra mes_compra  ano_compra  ano_mes
# 13161  alta floresta             MT         25          1        2018  2018-01
#
# [1 rows x 22 columns]

# %%
1299+104.66
# Out:
# 1403.66

# %%
#verificando na base de pagamentos
pagamentos[pagamentos.order_id == 'ce6d150fb29ada17d2082f4847107665']
# Out:
#                                order_id                       customer_id  \
# 12123  ce6d150fb29ada17d2082f4847107665  d8acb46c718975948423dbf1b603b959
#
#       order_status order_purchase_timestamp order_approved_at  \
# 12123    delivered               2018-01-25        2018-01-27
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 12123                   2018-01-29                    2018-02-21
#
#       order_estimated_delivery_date  payment_sequential payment_type  \
# 12123                    2018-03-08                   1  credit_card
#
#        payment_installments  payment_value
# 12123                    10        1586.47

# %%
#retirando valores nulos da base de vendas

vendas = vendas[vendas.price.notnull()]

# %%
#verificando os valores nulos
vendas.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1156
# order_delivered_customer_date    2402
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name            1598
# customer_unique_id                  0
# customer_city                       0
# customer_state                      0
# dia_compra                          0
# mes_compra                          0
# ano_compra                          0
# ano_mes                             0
# dtype: int64

# %%
#verificando a coluna 'order_delivered_customer_date' nula

vendas[vendas.order_delivered_customer_date.isnull()]
# Out:
#                                 order_id                       customer_id  \
# 6       136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 46      ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 115     0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 143     15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 180     6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                  ...                               ...
# 111583  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 111592  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 111593  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 111635  636cdd02667dc8d76d9296bf20a6890a  c162256b133c76f79181ce61d66545db
# 111787  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#        order_status order_purchase_timestamp order_approved_at  \
# 6          invoiced               2017-04-11        2017-04-13
# 46          shipped               2018-06-04        2018-06-05
# 115        invoiced               2018-08-03        2018-08-07
# 143      processing               2017-09-03        2017-09-03
# 180         shipped               2018-01-10        2018-01-11
# ...             ...                      ...               ...
# 111583   processing               2017-12-26        2017-12-26
# 111592     canceled               2017-10-01        2017-10-01
# 111593     canceled               2017-10-01        2017-10-01
# 111635      shipped               2018-02-17        2018-02-20
# 111787   processing               2018-01-05        2018-01-09
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 6                               NaT                           NaT
# 46                       2018-06-05                           NaT
# 115                             NaT                           NaT
# 143                             NaT                           NaT
# 180                      2018-01-11                           NaT
# ...                             ...                           ...
# 111583                          NaT                           NaT
# 111592                          NaT                           NaT
# 111593                          NaT                           NaT
# 111635                   2018-02-20                           NaT
# 111787                          NaT                           NaT
#
#        order_estimated_delivery_date  order_item_id  \
# 6                         2017-05-09            1.0
# 46                        2018-06-28            1.0
# 115                       2018-08-21            1.0
# 143                       2017-10-03            1.0
# 180                       2018-02-07            1.0
# ...                              ...            ...
# 111583                    2018-01-26            1.0
# 111592                    2017-10-27            1.0
# 111593                    2017-10-27            2.0
# 111635                    2018-03-14            1.0
# 111787                    2018-02-06            1.0
#
#                               product_id  ...   price freight_value  \
# 6       a1804276d9941ac0733cfd409f5206eb  ...   49.90         16.05
# 46      c50ca07e9e4db9ea5011f06802c0aea0  ...   14.49          7.87
# 115     1522589c64efd46731d3522568e5bc83  ...   35.00         15.35
# 143     61d52f4882421048afd530db53d6f230  ...  125.90         12.38
# 180     ee0c1cf2fbeae95205b4aa506f1469f0  ...   53.99         15.13
# ...                                  ...  ...     ...           ...
# 111583  aa428a8e4d587520f90d37a08030a812  ...   96.90         16.44
# 111592  dc2410804cf782c5d87dbcd201b74e9b  ...  150.00         16.81
# 111593  dc2410804cf782c5d87dbcd201b74e9b  ...  150.00         16.81
# 111635  52c80cedd4e90108bf4fa6a206ef6b03  ...  179.00         45.71
# 111787  0a57f7d2c983bcf8188589a5fea4a8da  ...  129.90         14.66
#
#          product_category_name                customer_unique_id  \
# 6                          NaN  36edbb3fb164b1f16485364b6fb04c73
# 46                beleza_saude  08fb46d35bb3ab4037202c23592d1259
# 115           artigos_de_natal  c7f8d7b1fffc946d7069574f74c39f4e
# 143                 perfumaria  9f269af9c49244f6ba4a46985a3cfc2e
# 180                 perfumaria  528b011eb7fab3d59c336cc7248eed3a
# ...                        ...                               ...
# 111583              brinquedos  43fb4e33ebe4ac765e99c7b57e5d6940
# 111592  informatica_acessorios  0f75924cbbe60142068f4029d744b724
# 111593  informatica_acessorios  0f75924cbbe60142068f4029d744b724
# 111635      ferramentas_jardim  39552b92919b5aacffcd326b13af0397
# 111787      relogios_presentes  965191786b70912f793e4a777fd623cd
#
#                     customer_city customer_state dia_compra mes_compra  \
# 6                      santa rosa             RS         11          4
# 46                        jundiai             SP          4          6
# 115     santo amaro da imperatriz             SC          3          8
# 143                     sao paulo             SP          3          9
# 180                      paracatu             MG         10          1
# ...                           ...            ...        ...        ...
# 111583                 aquidauana             MS         26         12
# 111592                   curitiba             PR          1         10
# 111593                   curitiba             PR          1         10
# 111635                    taubate             SP         17          2
# 111787                   campinas             SP          5          1
#
#         ano_compra  ano_mes
# 6             2017  2017-04
# 46            2018  2018-06
# 115           2018  2018-08
# 143           2017  2017-09
# 180           2018  2018-01
# ...            ...      ...
# 111583        2017  2017-12
# 111592        2017  2017-10
# 111593        2017  2017-10
# 111635        2018  2018-02
# 111787        2018  2018-01
#
# [2402 rows x 22 columns]

# %%
#verificando todos os status

vendas.loc[vendas.order_delivered_customer_date.isnull(), 'order_status'].value_counts()
# Out:
# shipped       1171
# canceled       525
# processing     355
# invoiced       340
# delivered        8
# approved         3
# Name: order_status, dtype: int64

# %%
#retirando vendas onde o status foi cancelado
vendas = vendas.loc[vendas.order_status != 'canceled']

# %%
#verificando os valores nulos
vendas.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date      700
# order_delivered_customer_date    1877
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name            1584
# customer_unique_id                  0
# customer_city                       0
# customer_state                      0
# dia_compra                          0
# mes_compra                          0
# ano_compra                          0
# ano_mes                             0
# dtype: int64

# %% [markdown]
# **Substituindo produtos sem categoria por outros**

# %%
#filtrando base para produtos sem categoria
vendas[vendas.product_category_name.isnull()]
# Out:
#                                 order_id                       customer_id  \
# 6       136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 119     bfe42c22ecbf90bc9f35cf591270b6a7  803ac05904124294f8767894d6da532b
# 207     58ac1947c1a9067b9f416cba6d844a3f  ee8e1d37f563ecc11cc4dcb4dfd794c2
# 259     e22b71f6e4a481445ec4527cb4c405f7  1faf89c8f142db3fca6cf314c51a37b6
# 297     a094215e786240fcfefb83d18036a1cd  86acfb656743da0c113d176832c9d535
# ...                                  ...                               ...
# 111503  1a10e938a1c7d8e5eecc3380f71ca76b  8a81607347c25d881d995d94de6ad824
# 111673  e33865519137f5737444109ae8438633  64b086bdcc54458af3ea3bd838db54a5
# 111680  f0dd9af88d8ef5a8e4670fbbedaf19c4  30ddb50bd22ee927ebe308ea3da60735
# 111686  272874573723eec18f23c0471927d778  48e080c8001e92ebea2b64e474f91a60
# 111703  dff2b9b8d7cfc595836945e1443789c3  2436fb2666a65fbacae82532e797cabf
#
#        order_status order_purchase_timestamp order_approved_at  \
# 6          invoiced               2017-04-11        2017-04-13
# 119       delivered               2018-01-27        2018-01-27
# 207       delivered               2017-09-13        2017-09-13
# 259       delivered               2017-04-22        2017-04-22
# 297       delivered               2018-02-08        2018-02-08
# ...             ...                      ...               ...
# 111503    delivered               2018-07-25        2018-07-26
# 111673    delivered               2018-05-28        2018-05-29
# 111680    delivered               2017-09-02        2017-09-05
# 111686    delivered               2017-12-20        2017-12-20
# 111703    delivered               2018-07-16        2018-07-17
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 6                               NaT                           NaT
# 119                      2018-02-03                    2018-02-09
# 207                      2017-09-14                    2017-09-21
# 259                      2017-04-24                    2017-05-02
# 297                      2018-02-09                    2018-02-19
# ...                             ...                           ...
# 111503                   2018-07-27                    2018-08-01
# 111673                   2018-05-30                    2018-06-01
# 111680                   2017-09-14                    2017-09-15
# 111686                   2017-12-21                    2017-12-26
# 111703                   2018-07-17                    2018-07-20
#
#        order_estimated_delivery_date  order_item_id  \
# 6                         2017-05-09            1.0
# 119                       2018-02-26            1.0
# 207                       2017-09-25            1.0
# 259                       2017-05-11            1.0
# 297                       2018-02-22            1.0
# ...                              ...            ...
# 111503                    2018-08-10            1.0
# 111673                    2018-06-20            1.0
# 111680                    2017-09-19            1.0
# 111686                    2018-01-09            1.0
# 111703                    2018-08-07            1.0
#
#                               product_id  ...   price freight_value  \
# 6       a1804276d9941ac0733cfd409f5206eb  ...   49.90         16.05
# 119     71225f49be70df4297892f6a5fa62171  ...   27.30         15.10
# 207     9820e04e332fc450d6fd975befc1bc28  ...  110.00         14.16
# 259     3bc5164bc7f4be77002d6651da65c98c  ...   22.50         11.74
# 297     5a848e4ab52fd5445cdc07aab1c40e48  ...  122.99          9.06
# ...                                  ...  ...     ...           ...
# 111503  8d39a63db6a98e40571f486e0c711cf7  ...  127.20         18.99
# 111673  e9cbc0910ab050cbd92fbeb051c270ea  ...   33.85          8.29
# 111680  0c877471e35049402bca235e06cb8063  ...   84.90         15.35
# 111686  5a848e4ab52fd5445cdc07aab1c40e48  ...  122.99          9.06
# 111703  bfa0e398bef2d28bb421d42997982cab  ...  219.99         15.13
#
#         product_category_name                customer_unique_id  \
# 6                         NaN  36edbb3fb164b1f16485364b6fb04c73
# 119                       NaN  34c58672601f2c6d29db7efd1f6bf958
# 207                       NaN  5cbf29b2dcf212a6a5d864b887238c72
# 259                       NaN  1268b060098ed3f22c2e7c34cc72a1a8
# 297                       NaN  f5cb81f98962f7504bef1e75579b6dff
# ...                       ...                               ...
# 111503                    NaN  75fe53e03a8a9797acb680ce8710da8b
# 111673                    NaN  82ffeb20040f58e6c008e4402fa6f992
# 111680                    NaN  1d627d8a6e1e33ea8eeeb7a17d998660
# 111686                    NaN  da59579685bd771fdd4f90fb50d28cd3
# 111703                    NaN  9b352d0736779ff0e21fcbd59a7141b3
#
#                 customer_city customer_state dia_compra mes_compra  \
# 6                  santa rosa             RS         11          4
# 119     bonfinopolis de minas             MG         27          1
# 207                 sao paulo             SP         13          9
# 259                 itapagipe             MG         22          4
# 297                 americana             SP          8          2
# ...                       ...            ...        ...        ...
# 111503          volta redonda             RJ         25          7
# 111673              sao paulo             SP         28          5
# 111680                 santos             SP          2          9
# 111686              guarulhos             SP         20         12
# 111703         rio de janeiro             RJ         16          7
#
#         ano_compra  ano_mes
# 6             2017  2017-04
# 119           2018  2018-01
# 207           2017  2017-09
# 259           2017  2017-04
# 297           2018  2018-02
# ...            ...      ...
# 111503        2018  2018-07
# 111673        2018  2018-05
# 111680        2017  2017-09
# 111686        2017  2017-12
# 111703        2018  2018-07
#
# [1584 rows x 22 columns]

# %%
#pegando apenas a coluna de categoria
vendas.loc[vendas.product_category_name.isnull(), 'product_category_name']
# Out:
# 6         NaN
# 119       NaN
# 207       NaN
# 259       NaN
# 297       NaN
#          ...
# 111503    NaN
# 111673    NaN
# 111680    NaN
# 111686    NaN
# 111703    NaN
# Name: product_category_name, Length: 1584, dtype: object

# %%
#trocando os valores
vendas.loc[vendas.product_category_name.isnull(), 'product_category_name'] = 'outros'

# %%
#verificando valores nulos
vendas.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date      700
# order_delivered_customer_date    1877
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name               0
# customer_unique_id                  0
# customer_city                       0
# customer_state                      0
# dia_compra                          0
# mes_compra                          0
# ano_compra                          0
# ano_mes                             0
# dtype: int64

# %% [markdown]
# **Verificar dados após tratrar dados vasios**

# %%
vendas.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered               2017-10-02        2017-10-02
# 1    delivered               2018-07-24        2018-07-26
# 2    delivered               2018-08-08        2018-08-08
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                   2017-10-04                    2017-10-10
# 1                   2018-07-26                    2018-08-07
# 2                   2018-08-08                    2018-08-17
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18            1.0
# 1                    2018-08-13            1.0
# 2                    2018-09-04            1.0
#
#                          product_id  ...   price freight_value  \
# 0  87285b34884572647811a353c7ac498a  ...   29.99          8.72
# 1  595fac2a385ac33a80bd5114aec74eb8  ...  118.70         22.76
# 2  aa4383b373c6aca5d8797843e5594415  ...  159.90         19.22
#
#    product_category_name                customer_unique_id customer_city  \
# 0  utilidades_domesticas  7c396fd4830fd04220f754e42b4e5bff     sao paulo
# 1             perfumaria  af07308b275d755c9edb36a90c618231     barreiras
# 2             automotivo  3a653a41f6f9fc3d2a113cf8398680e8    vianopolis
#
#   customer_state dia_compra mes_compra  ano_compra  ano_mes
# 0             SP          2         10        2017  2017-10
# 1             BA         24          7        2018  2018-07
# 2             GO          8          8        2018  2018-08
#
# [3 rows x 22 columns]

# %%
#verificando a soma de vendas por dia
vendas.groupby('order_purchase_timestamp')['price'].sum()
# Out:
# order_purchase_timestamp
# 2017-01-06      916.38
# 2017-01-07     1351.90
# 2017-01-08      709.58
# 2017-01-09      673.79
# 2017-01-10     1434.87
#                 ...
# 2018-08-16    35166.77
# 2018-08-17    31683.18
# 2018-08-18    24340.95
# 2018-08-19    25487.39
# 2018-08-20    34479.50
# Name: price, Length: 592, dtype: float64

# %%
#mostrando em grafico
vendas.groupby('order_purchase_timestamp')['price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
#em boxplot
vendas.groupby('order_purchase_timestamp')['price'].sum().plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Isolando valores**

# %%
import datetime as dt

# %%
#fazendo filtro em periodo exato
vendas[(vendas.order_purchase_timestamp >= dt.datetime(2017, 11, 18)) & 
        (vendas.order_purchase_timestamp <= dt.datetime(2017, 11, 27))
].groupby('order_purchase_timestamp')['price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
#eliminado uma data da base
vendas = vendas[vendas.order_purchase_timestamp != dt.datetime(2017, 11, 24)]

# %%
#revendo os dados em grafico
vendas.groupby('order_purchase_timestamp')['price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
#revendo os dados em plotbox
vendas.groupby('order_purchase_timestamp')['price'].sum().plot.box()
# Out:
# <AxesSubplot:>

# %%
#refazendo filtro em periodo exato
vendas[(vendas.order_purchase_timestamp >= dt.datetime(2017, 11, 18)) & 
        (vendas.order_purchase_timestamp <= dt.datetime(2017, 11, 27))
].groupby('order_purchase_timestamp')['price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
#eliminado o dia 25 da base
vendas = vendas[vendas.order_purchase_timestamp != dt.datetime(2017, 11, 25)]

# %%
#revendo os dados em grafico
vendas.groupby('order_purchase_timestamp')['price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
#revendo os dados em plotbox
vendas.groupby('order_purchase_timestamp')['price'].sum().plot.box()
# Out:
# <AxesSubplot:>

# %%
#refazendo filtro em periodo exato
vendas[(vendas.order_purchase_timestamp >= dt.datetime(2017, 11, 18)) & 
        (vendas.order_purchase_timestamp <= dt.datetime(2017, 11, 27))
].groupby('order_purchase_timestamp')['price'].sum().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %%
# vendo concentração de venda por estado
vendas.groupby('customer_state')['price'].sum().sort_values(ascending=True).plot.barh()
# Out:
# <AxesSubplot:ylabel='customer_state'>

# %%
# vendo a venda quantidade em relação ao tempo
vendas.groupby('order_purchase_timestamp')['price'].count().plot()
# Out:
# <AxesSubplot:xlabel='order_purchase_timestamp'>

# %% [markdown]
# **Observe a ordem 1b15974a0141d54e36626dca3fdc731a**

# %%
# vendo quantas vezes essa ordem aparece
vendas[vendas.order_id == '1b15974a0141d54e36626dca3fdc731a']
# Out:
#                                order_id                       customer_id  \
# 97752  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97753  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97754  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97755  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97756  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97757  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97758  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97759  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97760  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97761  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97762  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97763  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97764  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97765  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97766  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97767  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97768  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97769  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97770  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
# 97771  1b15974a0141d54e36626dca3fdc731a  be1b70680b9f9694d8c70f41fa3dc92b
#
#       order_status order_purchase_timestamp order_approved_at  \
# 97752    delivered               2018-02-22        2018-02-24
# 97753    delivered               2018-02-22        2018-02-24
# 97754    delivered               2018-02-22        2018-02-24
# 97755    delivered               2018-02-22        2018-02-24
# 97756    delivered               2018-02-22        2018-02-24
# 97757    delivered               2018-02-22        2018-02-24
# 97758    delivered               2018-02-22        2018-02-24
# 97759    delivered               2018-02-22        2018-02-24
# 97760    delivered               2018-02-22        2018-02-24
# 97761    delivered               2018-02-22        2018-02-24
# 97762    delivered               2018-02-22        2018-02-24
# 97763    delivered               2018-02-22        2018-02-24
# 97764    delivered               2018-02-22        2018-02-24
# 97765    delivered               2018-02-22        2018-02-24
# 97766    delivered               2018-02-22        2018-02-24
# 97767    delivered               2018-02-22        2018-02-24
# 97768    delivered               2018-02-22        2018-02-24
# 97769    delivered               2018-02-22        2018-02-24
# 97770    delivered               2018-02-22        2018-02-24
# 97771    delivered               2018-02-22        2018-02-24
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 97752                   2018-03-02                    2018-03-05
# 97753                   2018-03-02                    2018-03-05
# 97754                   2018-03-02                    2018-03-05
# 97755                   2018-03-02                    2018-03-05
# 97756                   2018-03-02                    2018-03-05
# 97757                   2018-03-02                    2018-03-05
# 97758                   2018-03-02                    2018-03-05
# 97759                   2018-03-02                    2018-03-05
# 97760                   2018-03-02                    2018-03-05
# 97761                   2018-03-02                    2018-03-05
# 97762                   2018-03-02                    2018-03-05
# 97763                   2018-03-02                    2018-03-05
# 97764                   2018-03-02                    2018-03-05
# 97765                   2018-03-02                    2018-03-05
# 97766                   2018-03-02                    2018-03-05
# 97767                   2018-03-02                    2018-03-05
# 97768                   2018-03-02                    2018-03-05
# 97769                   2018-03-02                    2018-03-05
# 97770                   2018-03-02                    2018-03-05
# 97771                   2018-03-02                    2018-03-05
#
#       order_estimated_delivery_date  order_item_id  \
# 97752                    2018-03-08            1.0
# 97753                    2018-03-08            2.0
# 97754                    2018-03-08            3.0
# 97755                    2018-03-08            4.0
# 97756                    2018-03-08            5.0
# 97757                    2018-03-08            6.0
# 97758                    2018-03-08            7.0
# 97759                    2018-03-08            8.0
# 97760                    2018-03-08            9.0
# 97761                    2018-03-08           10.0
# 97762                    2018-03-08           11.0
# 97763                    2018-03-08           12.0
# 97764                    2018-03-08           13.0
# 97765                    2018-03-08           14.0
# 97766                    2018-03-08           15.0
# 97767                    2018-03-08           16.0
# 97768                    2018-03-08           17.0
# 97769                    2018-03-08           18.0
# 97770                    2018-03-08           19.0
# 97771                    2018-03-08           20.0
#
#                              product_id  ...  price freight_value  \
# 97752  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97753  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97754  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97755  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97756  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97757  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97758  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97759  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97760  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97761  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97762  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97763  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97764  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97765  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97766  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97767  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97768  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97769  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97770  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
# 97771  ee3d532c8a438679776d222e997606b3  ...  100.0         10.12
#
#         product_category_name                customer_unique_id customer_city  \
# 97752  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97753  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97754  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97755  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97756  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97757  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97758  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97759  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97760  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97761  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97762  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97763  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97764  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97765  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97766  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97767  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97768  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97769  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97770  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
# 97771  informatica_acessorios  c402f431464c72e27330a67f7b94d4fb     sao paulo
#
#       customer_state dia_compra mes_compra  ano_compra  ano_mes
# 97752             SP         22          2        2018  2018-02
# 97753             SP         22          2        2018  2018-02
# 97754             SP         22          2        2018  2018-02
# 97755             SP         22          2        2018  2018-02
# 97756             SP         22          2        2018  2018-02
# 97757             SP         22          2        2018  2018-02
# 97758             SP         22          2        2018  2018-02
# 97759             SP         22          2        2018  2018-02
# 97760             SP         22          2        2018  2018-02
# 97761             SP         22          2        2018  2018-02
# 97762             SP         22          2        2018  2018-02
# 97763             SP         22          2        2018  2018-02
# 97764             SP         22          2        2018  2018-02
# 97765             SP         22          2        2018  2018-02
# 97766             SP         22          2        2018  2018-02
# 97767             SP         22          2        2018  2018-02
# 97768             SP         22          2        2018  2018-02
# 97769             SP         22          2        2018  2018-02
# 97770             SP         22          2        2018  2018-02
# 97771             SP         22          2        2018  2018-02
#
# [20 rows x 22 columns]

# %%
# Podemos isolar apenas a base de ordens e datas do pedido
vendas.loc[vendas.order_id == '1b15974a0141d54e36626dca3fdc731a',['order_id','order_purchase_timestamp']]
# Out:
#                                order_id order_purchase_timestamp
# 97752  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97753  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97754  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97755  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97756  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97757  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97758  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97759  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97760  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97761  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97762  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97763  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97764  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97765  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97766  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97767  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97768  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97769  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97770  1b15974a0141d54e36626dca3fdc731a               2018-02-22
# 97771  1b15974a0141d54e36626dca3fdc731a               2018-02-22

# %%
# eliminar os valores duplicados dessa base
vendas.loc[vendas.order_id == '1b15974a0141d54e36626dca3fdc731a',['order_id','order_purchase_timestamp']].drop_duplicates()
# Out:
#                                order_id order_purchase_timestamp
# 97752  1b15974a0141d54e36626dca3fdc731a               2018-02-22

# %%
vendas_qtd = vendas[['order_id','order_purchase_timestamp']]
vendas_qtd = vendas_qtd.drop_duplicates()

# %%
# Agora observe novamente essa ordem
vendas_qtd[vendas_qtd.order_id == '1b15974a0141d54e36626dca3fdc731a']
# Out:
#                                order_id order_purchase_timestamp
# 97752  1b15974a0141d54e36626dca3fdc731a               2018-02-22

# %%
# Dessa forma, podemos traçar esse gráfico de forma correta
vendas.groupby('order_purchase_timestamp')['order_id'].count().plot();

# %% [markdown]
# **Podemos também filtrar a base de venda valor já tratada para alguma categoria específica**

# %%
# Verificando as categorias mais frequentes
vendas.groupby('product_category_name')['price'].count().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                                  10712
# beleza_saude                                      9331
# esporte_lazer                                     8363
# moveis_decoracao                                  7982
# informatica_acessorios                            7606
#                                                  ...
# cds_dvds_musicais                                   14
# portateis_cozinha_e_preparadores_de_alimentos       13
# pc_gamer                                             8
# fashion_roupa_infanto_juvenil                        8
# seguros_e_servicos                                   2
# Name: price, Length: 74, dtype: int64

# %%
# Verificando por valor vendido
vendas.groupby('product_category_name')['price'].sum().sort_values(ascending=False)
# Out:
# product_category_name
# beleza_saude                     1215371.11
# relogios_presentes               1166708.22
# cama_mesa_banho                  1001616.80
# esporte_lazer                     956416.10
# informatica_acessorios            885143.81
#                                     ...
# flores                              1110.04
# casa_conforto_2                      760.27
# cds_dvds_musicais                    730.00
# fashion_roupa_infanto_juvenil        569.85
# seguros_e_servicos                   283.29
# Name: price, Length: 74, dtype: float64
